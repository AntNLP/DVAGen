# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("/home/weidu/public/pretrain/meta-llama/Llama-2-7b-chat-hf")
text = "ArithmeticError"

# %%
toeknized_text = tokenizer.tokenize(text)
print(toeknized_text)
# Out:
# ['▁Ar', 'ithmetic', 'Error']

# %%
print(tokenizer.convert_tokens_to_string(toeknized_text[0:1]))
# Out:
# Ar

# %%
a = [[1,2],[3,4,5],[6,7]]
# combine all sublists into a single list
a = sum(a, [])
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]
